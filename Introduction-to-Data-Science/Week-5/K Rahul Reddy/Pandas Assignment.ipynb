# %% [markdown]
# # 1)

# %%
import numpy as np
import pandas as pd
Match_data = pd.read_csv("DIM_PLAYER_MATCH.csv", encoding = "ISO-8859-1", delimiter = ',', skiprows = [1])
Match_data.head()
# Out:
#    Player_match_SK  PlayerMatch_key  Match_Id  Player_Id Player_Name  \
# 0            12694      33598700006    335987          6    R Dravid
# 1            12695      33598700007    335987          7    W Jaffer
# 2            12696      33598700008    335987          8     V Kohli
# 3            12697      33598700009    335987          9   JH Kallis
# 4            12698      33598700010    335987         10    CL White
#
#           DOB    Batting_hand          Bowling_skill  Country_Name Role_Desc  \
# 0  1973-01-11  Right-hand bat     Right-arm offbreak         India   Captain
# 1  1978-02-16  Right-hand bat     Right-arm offbreak         India    Player
# 2  1988-11-05  Right-hand bat       Right-arm medium         India    Player
# 3  1975-10-16  Right-hand bat  Right-arm fast-medium  South Africa    Player
# 4  1983-08-18  Right-hand bat        Legbreak googly     Australia    Player
#
#        ...       Season_year is_manofThematch  Age_As_on_match  \
# ...

# %%
young = Match_data[Match_data.Age_As_on_match < 25][['Player_Id','Player_Name', 'Batting_hand', 'Bowling_skill', 'Season_year', 'Player_team', 'is_manofThematch']]

# %%
data = Match_data[['Player_Id','Player_Name', 'Batting_hand', 'Bowling_skill', 'Season_year', 'Player_team', 'is_manofThematch']]

# %%
percent = []
team = []
for year in range(2008,2018):
    team += [young[young.Season_year == year].Player_team.value_counts().index[0]]
    percent += [len(young.Player_Id[young.Season_year == year].unique())/len(data.Player_Id[data.Season_year == year].unique())*100]

# %%
pd.DataFrame([percent, team],columns = data.Season_year.unique(), index = ['Percentage of young players', 'Team with maximum young players '])
# Out:
#                                               2008             2009  \
# Percentage of young players                36.1963          32.1212
# Team with maximum young players   Delhi Daredevils  Deccan Chargers
#
#                                              2010  \
# Percentage of young players               29.2818
# Team with maximum young players   Deccan Chargers
#
#                                                          2011  \
# Percentage of young players                           25.6281
# Team with maximum young players   Royal Challengers Bangalore
#
#                                              2012             2013  \
# Percentage of young players               27.8947          25.8883
# Team with maximum young players   Kings XI Punjab  Kings XI Punjab
#
#                                              2014              2015  \
# Percentage of young players                    25            22.069
# Team with maximum young players   Kings XI Punjab  Rajasthan Royals
#
# ...

# %%
percent_MOM = len(young[young.is_manofThematch == 1])/len(data[data.is_manofThematch == 1])*100
print("Percent of young players winning Man Of the Match =", percent_MOM)
# Out:
# Percent of young players winning Man Of the Match = 17.591125198098258

# %% [markdown]
# # 2)

# %%
if len(Match_data.Batting_hand.value_counts()) == 5:
    Match_data.Batting_hand.loc[Match_data.Batting_hand.str.contains('Right')] = 'Right'
    Match_data.Batting_hand.loc[Match_data.Batting_hand.str.contains('Left')] = 'Left'
Match_data.Batting_hand.value_counts().sum()
# Out:
# /home/hackspot/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# 13992

# %%
if len(Match_data.Bowling_skill.value_counts()) == 20:
    Match_data.Bowling_skill.loc[Match_data.Bowling_skill.notnull() == False] = 'None'
    Match_data.Bowling_skill.loc[Match_data.Bowling_skill.str.contains('Right')] = 'Right'
    Match_data.Bowling_skill.loc[Match_data.Bowling_skill.str.contains('eft')] = 'Left'
    Match_data.Bowling_skill.loc[Match_data.Bowling_skill.str.contains('break')] = 'None'
Match_data.Bowling_skill.value_counts().sum()
# Out:
# /home/hackspot/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# 13992

# %%
if len(Match_data.Bowling_skill.value_counts()) == 3:
    Match_data.Bowling_skill.loc[Match_data.Bowling_skill.str.contains('None')] = Match_data[Match_data.Bowling_skill.str.contains('None')]['Batting_hand']
# Out:
# /home/hackspot/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
Right_Bat = Match_data[Match_data.Batting_hand == 'Right']
Right_Bowl = Match_data[Match_data.Bowling_skill == 'Right']
Left_Bat = Match_data[Match_data.Batting_hand == 'Left']
Left_Bowl = Match_data[Match_data.Bowling_skill == 'Left']
Right = pd.concat([Right_Bat,Right_Bowl])
Left = pd.concat([Left_Bat, Left_Bowl])
print("Percentage of Left Players winning MOM =", len(Left[Left.is_manofThematch ==1])/len(Left)*100)
print("Percentage of Right Players winning MOM =", len(Right[Right.is_manofThematch == 1])/len(Right)*100)
print("Left Players have performed better")
# Out:
# Percentage of Left Players winning MOM = 4.750321934468451
# Percentage of Right Players winning MOM = 4.429626101452727
# Left Players have performed better

# %%
Match_Data = pd.read_csv("DIM_PLAYER_MATCH.csv", encoding = "ISO-8859-1", delimiter = ',', skiprows = [1])

# %%
Match_Data.Bowling_skill.value_counts()
# Out:
# Right-arm offbreak        3359
# Right-arm medium          3083
# Slow left-arm orthodox    1221
# Right-arm medium-fast     1070
# Right-arm fast-medium      996
# Legbreak                   774
# Legbreak googly            662
# Right-arm fast             584
# Left-arm fast-medium       393
# Left-arm medium-fast       310
# Left-arm medium            162
# Left-arm fast              104
# Slow left-arm chinaman      61
# Right-arm bowler            36
#  Right-arm fast-medium      12
#  Right-arm offbreak         11
#  Legbreak                    7
#  Right-arm medium-fast       6
# Right-arm medium fast        6
#  Left-arm fast               5
# Name: Bowling_skill, dtype: int64

# %%
if len(Match_Data.Bowling_skill.value_counts()) == 20:
    Match_Data.Bowling_skill.loc[Match_Data.Bowling_skill.notnull() == False] = 'None'
    Match_Data.Bowling_skill.loc[Match_Data.Bowling_skill.str.contains('break')] = 'Spin'
    Match_Data.Bowling_skill.loc[Match_Data.Bowling_skill.str.contains('fast')] = 'Pace'
    Match_Data.Bowling_skill.loc[Match_Data.Bowling_skill.str.contains('Slow')] = 'Spin'
    Match_Data.Bowling_skill.loc[Match_Data.Bowling_skill.str.contains('medium')] = 'Pace'
Match_Data.Bowling_skill.value_counts()
# Out:
# /home/hackspot/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Pace                6731
# Spin                6095
# None                1130
# Right-arm bowler      36
# Name: Bowling_skill, dtype: int64

# %%
Spin = Match_Data[Match_Data.Bowling_skill == 'Spin']
Pace= Match_Data[Match_Data.Bowling_skill == 'Pace']
print("Percentage of Spin Bowlers winning MOM =", len(Spin[Spin.is_manofThematch ==1])/len(Spin)*100)
print("Percentage of Pace Bowlers winning MOM =", len(Pace[Pace.is_manofThematch == 1])/len(Pace)*100)
print("Spin Players have performed better")
# Out:
# Percentage of Spin Bowlers winning MOM = 4.938474159146842
# Percentage of Pace Bowlers winning MOM = 4.531273213489824
# Spin Players have performed better

# %% [markdown]
# # 3)

# %%
M = pd.read_csv("DIM_PLAYER_MATCH.csv", encoding = "ISO-8859-1", delimiter = ',', skiprows = [1])
M.head()
# Out:
#    Player_match_SK  PlayerMatch_key  Match_Id  Player_Id Player_Name  \
# 0            12694      33598700006    335987          6    R Dravid
# 1            12695      33598700007    335987          7    W Jaffer
# 2            12696      33598700008    335987          8     V Kohli
# 3            12697      33598700009    335987          9   JH Kallis
# 4            12698      33598700010    335987         10    CL White
#
#           DOB    Batting_hand          Bowling_skill  Country_Name Role_Desc  \
# 0  1973-01-11  Right-hand bat     Right-arm offbreak         India   Captain
# 1  1978-02-16  Right-hand bat     Right-arm offbreak         India    Player
# 2  1988-11-05  Right-hand bat       Right-arm medium         India    Player
# 3  1975-10-16  Right-hand bat  Right-arm fast-medium  South Africa    Player
# 4  1983-08-18  Right-hand bat        Legbreak googly     Australia    Player
#
#        ...       Season_year is_manofThematch  Age_As_on_match  \
# ...

# %%
if len(M.Batting_hand.value_counts()) == 5:
    M.Batting_hand.loc[M.Batting_hand.str.contains('Right')] = 'Right'
    M.Batting_hand.loc[M.Batting_hand.str.contains('Left')] = 'Left'
# Out:
# /home/hackspot/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
M
# Out:
#        Player_match_SK  PlayerMatch_key  Match_Id  Player_Id  \
# 0                12694      33598700006    335987          6
# 1                12695      33598700007    335987          7
# 2                12696      33598700008    335987          8
# 3                12697      33598700009    335987          9
# 4                12698      33598700010    335987         10
# 5                12699      33598700011    335987         11
# 6                12700      33598700012    335987         12
# 7                12701      33598700013    335987         13
# 8                12702      33598700014    335987         14
# 9                12703      33598700015    335987         15
# 10               12704      33598700016    335987         16
# 11               12705      33598700001    335987          1
# 12               12706      33598700002    335987          2
# 13               12707      33598700003    335987          3
# ...

# %%
Team = []

# %%
Keeper = M[M.Role_Desc.str.contains('Keeper')][M.is_manofThematch == 1]['Player_Name'].value_counts().index[0]
Team.append(Keeper)
Team
# Out:
# /home/hackspot/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ['MS Dhoni']

# %%
Right_Hand_Batsmen = list(M[M.Bowling_skill.isnull() == 1][M.is_manofThematch== 1][M.Batting_hand == 'Right']['Player_Name'].value_counts().index[0:2])
Team += Right_Hand_Batsmen
Team
# Out:
# /home/hackspot/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ['MS Dhoni', 'KD Karthik', 'SV Samson']

# %%
Left_Hand_Batsmen = list(M[M.Bowling_skill.isnull() == 1][M.is_manofThematch== 1][M.Batting_hand == 'Left']['Player_Name'].value_counts().index[0:2])
Team += Left_Hand_Batsmen
Team
# Out:
# /home/hackspot/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ['MS Dhoni', 'KD Karthik', 'SV Samson', 'PA Patel', 'RR Pant']

# %%
All_Rounder = M[M.is_manofThematch== 1]['Player_Name'].value_counts().index[0]
Team.append(All_Rounder)
Team
# Out:
# ['MS Dhoni', 'KD Karthik', 'SV Samson', 'PA Patel', 'RR Pant', 'CH Gayle']

# %%
Spin = list(Match_Data[Match_Data.Bowling_skill == 'Spin'][Match_Data.is_manofThematch == 1]['Player_Name'].value_counts().index[[1, 2, ]])
Team += Spin
Team
# Out:
# /home/hackspot/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ['MS Dhoni',
#  'KD Karthik',
#  'SV Samson',
#  'PA Patel',
#  'RR Pant',
#  'CH Gayle',
#  'YK Pathan',
#  'DA Warner']

# %%
Pace = list(Match_Data[Match_Data.Bowling_skill == 'Pace'][Match_Data.is_manofThematch == 1]['Player_Name'].value_counts().index[[0,2,3]])
Team += Pace
Team
# Out:
# /home/hackspot/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ['MS Dhoni',
#  'KD Karthik',
#  'SV Samson',
#  'PA Patel',
#  'RR Pant',
#  'CH Gayle',
#  'YK Pathan',
#  'DA Warner',
#  'AB de Villiers',
#  'MEK Hussey',
#  'AM Rahane']

# %%
pd.DataFrame(Team, index = ['Keeper', 'Right Hand Batsman', 'Right Hand Batsman', 'Left Hand Batsman', 'Left Hand Batsman', 'All-rounder', 'Spin', 'Spin', 'Pace', 'Pace', 'Pace'],columns = ['Players'])
# Out:
#                            Players
# Keeper                    MS Dhoni
# Right Hand Batsman      KD Karthik
# Right Hand Batsman       SV Samson
# Left Hand Batsman         PA Patel
# Left Hand Batsman          RR Pant
# All-rounder               CH Gayle
# Spin                     YK Pathan
# Spin                     DA Warner
# Pace                AB de Villiers
# Pace                    MEK Hussey
# Pace                     AM Rahane

# %% [markdown]
# # 4)

# %%
M[M.IsPlayers_Team_won == 1]['Player_team'].value_counts()
# Out:
# Mumbai Indians                 1001
# Chennai Super Kings             869
# Kolkata Knight Riders           847
# Royal Challengers Bangalore     803
# Kings XI Punjab                 759
# Rajasthan Royals                693
# Delhi Daredevils                682
# Sunrisers Hyderabad             462
# Deccan Chargers                 319
# Rising Pune Supergiants         165
# Gujarat Lions                   143
# Pune Warriors                   132
# Kochi Tuskers Kerala             66
# kings XI Punjab                  11
# Name: Player_team, dtype: int64

# %%
if len(M.Player_team.value_counts()) == 15:
    M.Player_team.loc[M.Player_team.str.contains('Punjab')] = 'Kings XI Punjab'
    M.Player_team.loc[M.Player_team.str.contains('Hyderabad')] = 'Sunrisers Hyderabad'
    #print(team)
    #print(max(M[M.IsPlayers_Team_won == 1][M.Opposit_Team == team]['Player_team'].value_counts().index), max(M[M.IsPlayers_Team_won == 1][M.Opposit_Team == team]['Player_team'].value_counts())//11,'\n')
# Out:
# /home/hackspot/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
teams = []
Win = []
Loss = []
for team in M.Player_team.value_counts().index:
    teams.append(team) 
    Win.append(max(M[M.IsPlayers_Team_won == 1][M.Player_team == team]['Opposit_Team'].value_counts()//11))
    Loss.append(max(M[M.IsPlayers_Team_won == 0][M.Player_team == team]['Opposit_Team'].value_counts()//11))             
result = pd.DataFrame([Win, Loss], columns = teams, index = ['Max wins against one team', 'Max losses against one team'])
result
# Out:
# /home/hackspot/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/hackspot/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
#                              Mumbai Indians  Royal Challengers Bangalore  \
# Max wins against one team                16                           12
# Max losses against one team              10                           13
#
#                              Kings XI Punjab  Kolkata Knight Riders  \
# Max wins against one team                 12                     14
# Max losses against one team               14                     16
#
#                              Delhi Daredevils  Chennai Super Kings  \
# Max wins against one team                   9                   12
# Max losses against one team                13                   12
#
# ...

# %%
print(result.idxmax(axis = 1))
print(result.max(axis = 1))
# Out:
# Max wins against one team             Mumbai Indians
# Max losses against one team    Kolkata Knight Riders
# dtype: object
# Max wins against one team      16
# Max losses against one team    16
# dtype: int64

# %%
print(result.idxmax(axis = 1)[0], "won", result.max(axis = 1)[0], "matches against", result.idxmax(axis = 1)[1])
# Out:
# Mumbai Indians won 16 matches against Kolkata Knight Riders
